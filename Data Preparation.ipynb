# %% [markdown]
# # TEAM 2

# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import numpy

# %%
dftest = pd.read_csv('data_test.csv', delimiter=';')
dftest.drop('No. Urut', axis=1, inplace=True)
dftest.head()
# Out:
#       Z1     Z2     Z3     Z4     Z5     Z6     Z7     Z8     Z9    Z10  \
# 0  192.0  200.0   68.0  280.0  148.0  188.0  343.0  253.0  166.0  187.0
# 1  142.0   87.0    0.0  234.0  150.0  297.0    0.0  225.0   96.0  278.0
# 2  149.0  160.0   67.0  224.0  135.0  155.0  159.0  157.0  139.0  136.0
# 3  177.0  100.0  167.0  170.0   91.0  104.0   92.0   95.0  101.0  210.0
# 4  273.0   62.0  341.0  344.0  196.0   39.0  143.0  252.0  224.0    0.0
#
#      Z11    Z12    Z13    Z14    Z15    Z16
# 0  156.0  313.0  148.0   76.0   16.0  146.0
# 1    0.0  240.0   96.0   88.0  168.0  114.0
# 2  159.0  150.0  136.0  158.0  248.0  179.0
# 3   97.0  108.0   90.0  240.0  200.0   98.0
# 4  120.0  234.0  159.0   95.0  118.0   47.0

# %%
dftrain = pd.read_csv('data_train.csv', delimiter=';')
dftrain.head()
# Out:
#    No HURUF   Z1   Z2   Z3   Z4   Z5   Z6   Z7   Z8   Z9  Z10  Z11  Z12  Z13  \
# 0   1    HA  274   72  222  170  160  180  105  138  110  214  104  131  105
# 1   1    HA  114    3   77   87   56   51  104   94   56   45  164   61   36
# 2   1    HA  279  182  348  286  322  191  170  181  316  157  203  179  300
# 3   1    HA   92   53  202  117   67   76  153   83   66   75  146   78   56
# 4   1    HA  280   35  255  191  155  153  218  163  131  237  207  160  103
#
#    Z14  Z15  Z16
# 0  242  114  123
# 1   92  110   31
# 2  302  185  176
# 3  142   90   60
# 4  264  117  133

# %%
listHuruf = dftrain['HURUF'].unique()
listHuruf
# Out:
# array(['HA', nan, 'CA', 'RA', 'KA', 'DA', 'LA', 'TA', 'SA', 'WA', 'PA',
#        'DHA', 'JA', 'YA', 'NYA', 'MA', 'GA', 'BA', 'THA', 'NGA'],
#       dtype=object)

# %% [markdown]
# ## Memproses data NULL

# %% [markdown]
# *dari semua data

# %%
dftest[140:]
# Out:
#         Z1     Z2     Z3     Z4     Z5     Z6     Z7     Z8     Z9    Z10  \
# 140  165.0  102.0  147.0  253.0  100.0  254.0  169.0  307.0   90.0  150.0
# 141   93.0  148.0  209.0  143.0   78.0   77.0  172.0  261.0  141.0  144.0
# 142  231.0  414.0  100.0  371.0  364.0  128.0  198.0  274.0  239.0  379.0
# 143  126.0   98.0  169.0  234.0  245.0   93.0   34.0   99.0  206.0  134.0
# 144  266.0  163.0  287.0  159.0  182.0  468.0  274.0  211.0  190.0  205.0
# 145  169.0  127.0  111.0  133.0  112.0   97.0  108.0   98.0   99.0  125.0
# 146  163.0   68.0   64.0  273.0  119.0  160.0  112.0  153.0  101.0  145.0
# 147   36.0    0.0  232.0  172.0  210.0  131.0  323.0   71.0  154.0  157.0
# 148  244.0  168.0  290.0  290.0  185.0  178.0  142.0  185.0  240.0   91.0
# 149  117.0   68.0  282.0  210.0  119.0  111.0  179.0  134.0  115.0  116.0
# 150    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 151    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
dftest.dropna(inplace=True)

# %%
dftest.isnull().sum()
# Out:
# Z1     0
# Z2     0
# Z3     0
# Z4     0
# Z5     0
# Z6     0
# Z7     0
# Z8     0
# Z9     0
# Z10    0
# Z11    0
# Z12    0
# Z13    0
# Z14    0
# Z15    0
# Z16    0
# dtype: int64

# %%
dftrain.isnull().sum()
# Out:
# No        0
# HURUF    24
# Z1        0
# Z2        0
# Z3        0
# Z4        0
# Z5        0
# Z6        0
# Z7        0
# Z8        0
# Z9        0
# Z10       0
# Z11       0
# Z12       0
# Z13       0
# Z14       0
# Z15       0
# Z16       0
# dtype: int64

# %% [markdown]
# *Dari filter data

# %%
dftrain[['No','HURUF']][20:50]
# Out:
#     No HURUF
# 20   1    HA
# 21   1    HA
# 22   1    HA
# 23   2   NaN
# 24   2   NaN
# 25   2   NaN
# 26   2   NaN
# 27   2   NaN
# 28   2   NaN
# 29   2   NaN
# 30   2   NaN
# 31   2   NaN
# 32   2   NaN
# 33   2   NaN
# 34   2   NaN
# 35   2   NaN
# 36   2   NaN
# 37   2   NaN
# 38   2   NaN
# 39   2   NaN
# 40   2   NaN
# 41   2   NaN
# 42   2   NaN
# 43   2   NaN
# 44   2   NaN
# 45   2   NaN
# 46   2   NaN
# 47   3    CA
# 48   3    CA
# 49   3    CA

# %%
dftrain[['No','HURUF']][20:50].isnull().sum()
# Out:
# No        0
# HURUF    24
# dtype: int64

# %% [markdown]
# Data Null di isi

# %%
dftrain['HURUF'].fillna(value='NA', inplace=True)

# %%
dftrain.isnull().sum()
# Out:
# HURUF    0
# Z1       0
# Z2       0
# Z3       0
# Z4       0
# Z5       0
# Z6       0
# Z7       0
# Z8       0
# Z9       0
# Z10      0
# Z11      0
# Z12      0
# Z13      0
# Z14      0
# Z15      0
# Z16      0
# dtype: int64

# %% [markdown]
# ## Cek Kesamaan Jumlah Data

# %%
dftrain.describe()
# Out:
#                Z1          Z2          Z3          Z4          Z5          Z6  \
# count  450.000000  450.000000  450.000000  450.000000  450.000000  450.000000
# mean   167.551111  117.206667  160.411111  202.644444  123.248889  127.000000
# std     89.893742   93.541146  102.802630   86.359392   73.046681   77.899541
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    100.000000   49.000000   81.250000  140.000000   71.000000   73.000000
# 50%    151.500000   91.000000  149.500000  189.000000  110.000000  116.500000
# 75%    232.000000  165.750000  225.750000  252.000000  163.000000  166.500000
# max    528.000000  504.000000  457.000000  599.000000  427.000000  537.000000
#
#                Z7          Z8          Z9         Z10         Z11         Z12  \
# count  450.000000  450.000000  450.000000  450.000000  450.000000  450.000000
# mean   107.164444  150.871111  119.808889  138.537778  129.624444  146.600000
# ...

# %%
dftrain[9:10]
# Out:
#    No HURUF   Z1  Z2   Z3   Z4   Z5  Z6   Z7   Z8   Z9  Z10  Z11  Z12  Z13  \
# 9   1    HA  359   0  236  359  280   0  153  268  295    0  163  265  180
#
#    Z14  Z15  Z16
# 9  255  160  212

# %% [markdown]
# .

# %% [markdown]
# # Data Training
